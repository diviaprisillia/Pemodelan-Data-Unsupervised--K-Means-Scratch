# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from IPython.display import clear_output
from sklearn.cluster import KMeans

df = pd.read_csv('Student Stress Factors (2).csv')


df
# Out:
#      Kindly Rate your Sleep Quality 😴  \
# 0                                   3
# 1                                   4
# 2                                   2
# 3                                   3
# 4                                   2
# ..                                ...
# 515                                 3
# 516                                 2
# 517                                 2
# 518                                 3
# 519                                 5
#
#      How many times a week do you suffer headaches 🤕?  \
# 0                                                   1
# 1                                                   1
# 2                                                   1
# 3                                                   2
# 4                                                   3
# ..                                                ...
# 515                                                 2
# 516                                                 4
# ...

# %%
# Normalisasi nilai pada dataframe

df = ((df-df.min()) / (df.max() - df.min())) * 10 + 1

df
# Out:
#      Kindly Rate your Sleep Quality 😴  \
# 0                                 6.0
# 1                                 8.5
# 2                                 3.5
# 3                                 6.0
# 4                                 3.5
# ..                                ...
# 515                               6.0
# 516                               3.5
# 517                               3.5
# 518                               6.0
# 519                              11.0
#
#      How many times a week do you suffer headaches 🤕?  \
# 0                                                 1.0
# 1                                                 1.0
# 2                                                 1.0
# 3                                                 3.5
# 4                                                 6.0
# ..                                                ...
# 515                                               3.5
# 516                                               8.5
# ...

# %%
df.describe()
# Out:
#        Kindly Rate your Sleep Quality 😴  \
# count                        520.000000
# mean                           6.312500
# std                            2.747558
# min                            1.000000
# 25%                            3.500000
# 50%                            6.000000
# 75%                            8.500000
# max                           11.000000
#
#        How many times a week do you suffer headaches 🤕?  \
# count                                        520.000000
# mean                                           3.956731
# std                                            3.118648
# min                                            1.000000
# 25%                                            1.000000
# 50%                                            3.500000
# 75%                                            6.000000
# max                                           11.000000
#
#        How would you rate you academic performance 👩‍🎓?  \
# ...

# %%
def random_centroid(df, k):
    centroids = []
    for i in range(k):
        centroid = df.apply(lambda x: float(x.sample()))
        centroids.append(centroid)
    return pd.concat(centroids, axis=1)

centroids = random_centroid(df, 3)

centroids
# Out:
#                                                       0    1     2
# Kindly Rate your Sleep Quality 😴                    6.0  8.5   3.5
# How many times a week do you suffer headaches 🤕?    8.5  3.5   1.0
# How would you rate you academic performance 👩‍🎓?    1.0  6.0   6.0
# how would you rate your study load?                 1.0  8.5   8.5
# How many times a week you practice extracurricu...  3.5  1.0   8.5
# How would you rate your stress levels?              8.5  8.5  11.0

# %%
def get_clusters(df, centroids):
    euclideanDis = centroids.apply(lambda x: np.sqrt(((df - x)**2).sum(axis=1)))
    return euclideanDis.idxmin(axis=1)

clusters = get_clusters(df, centroids)

clusters.value_counts()
# Out:
# 1    235
# 2    170
# 0    115
# dtype: int64

# %%
def new_centroids(df, clusters, k):
    centroids = df.groupby(clusters).apply(lambda x: np.exp(np.log(x).mean())).T
    return centroids

def clusters_plot(df, clusters, centroids, iteration):
    pca = PCA(n_components=2)
    df2D = pca.fit_transform(df)
    centroids2D = pca.transform(centroids.T)
    clear_output(wait=True)
    plt.title(f'Iteration {iteration}')
    plt.scatter(x=df2D[:,0], y=df2D[:,1], c=clusters)
    plt.scatter(x=centroids2D[:,0], y=centroids2D[:,1])
    plt.show()
    
max_iter = 3
centroid_count = 3

centroids = random_centroid(df, centroid_count)
old_centroids = pd.DataFrame()
iteration = 1

while iteration < max_iter and not centroids.equals(old_centroids):
    old_centroids = centroids
    clusters = get_clusters(df, centroids)
    centroids = new_centroids(df, clusters, centroid_count)
    clusters_plot(df, clusters, centroids, iteration)
    iteration += 1

# %%
centroids
# Out:
#                                                            0         1  \
# Kindly Rate your Sleep Quality 😴                    6.642205  4.010826
# How many times a week do you suffer headaches 🤕?    3.232525  2.211751
# How would you rate you academic performance 👩‍🎓?    6.570361  4.865009
# how would you rate your study load?                 2.483279  3.178578
# How many times a week you practice extracurricu...  3.195366  1.691710
# How would you rate your stress levels?              1.625662  5.309244
#
#                                                            2
# Kindly Rate your Sleep Quality 😴                    6.185695
# How many times a week do you suffer headaches 🤕?    2.881431
# How would you rate you academic performance 👩‍🎓?    6.689892
# how would you rate your study load?                 6.435921
# How many times a week you practice extracurricu...  6.919432
# How would you rate your stress levels?              6.940059

# %%
clusters.value_counts()
# Out:
# 2    220
# 1    160
# 0    140
# dtype: int64

# %%
Kmeans = KMeans(3)
Kmeans.fit(df)

pd.DataFrame(Kmeans.cluster_centers_, columns=df.columns).T
# Out:
#                                                            0         1  \
# Kindly Rate your Sleep Quality 😴                    6.568182  6.348837
# How many times a week do you suffer headaches 🤕?    2.931818  4.081395
# How would you rate you academic performance 👩‍🎓?    8.272727  6.988372
# how would you rate your study load?                 3.840909  8.325581
# How many times a week you practice extracurricu...  9.750000  5.593023
# How would you rate your stress levels?              3.954545  8.151163
#
#                                                            2
# Kindly Rate your Sleep Quality 😴                    6.128205
# How many times a week do you suffer headaches 🤕?    4.397436
# How would you rate you academic performance 👩‍🎓?    5.807692
# how would you rate your study load?                 2.987179
# How many times a week you practice extracurricu...  2.217949
# How would you rate your stress levels?              3.948718
